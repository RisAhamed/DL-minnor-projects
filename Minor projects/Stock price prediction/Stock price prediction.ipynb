# %% [markdown]
# The sourde file is [link text](https://)https://query1.finance.yahoo.com/v7/finance/download/INR=X?period1=1580035828&period2=1611658228&interval=1d&events=history&includeAdjustedClose=true

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/price.csv")

# %%
data
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 0    2020-01-27  71.320000  71.635002  71.320000  71.324997  71.324997       0
# 1    2020-01-28  71.654999  71.654999  71.178001  71.440002  71.440002       0
# 2    2020-01-29  71.230103  71.425003  71.168503  71.230400  71.230400       0
# 3    2020-01-30  71.300003  71.711998  71.300003  71.300003  71.300003       0
# 4    2020-01-31  71.639999  71.639999  71.277496  71.639999  71.639999       0
# ..          ...        ...        ...        ...        ...        ...     ...
# 257  2021-01-20  73.192001  73.192299  72.899300  73.191902  73.191902       0
# 258  2021-01-21  72.907898  73.045303  72.883003  72.910896  72.910896       0
# 259  2021-01-22  72.954903  73.237503  72.929001  72.954903  72.954903       0
# 260  2021-01-25  72.995903  73.220001  72.877998  72.995903  72.995903       0
# 261  2021-01-26  72.970001  73.222000  72.774498  72.970001  72.970001       0
#
# [262 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       262 non-null    object
#  1   Open       262 non-null    float64
#  2   High       262 non-null    float64
#  3   Low        262 non-null    float64
#  4   Close      262 non-null    float64
#  5   Adj Close  262 non-null    float64
#  6   Volume     262 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.5+ KB

# %%
data.isnull().sum(
    )
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 262 entries, 0 to 261
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 262 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.2 KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       262 non-null    datetime64[ns]
#  1   Open       262 non-null    float64
#  2   High       262 non-null    float64
#  3   Low        262 non-null    float64
#  4   Close      262 non-null    float64
#  5   Adj Close  262 non-null    float64
#  6   Volume     262 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 14.5 KB

# %%
data.sample(10)
# Out:
#           Date       Open       High        Low      Close  Adj Close  Volume
# 50  2020-04-06  76.230003  77.379997  75.904503  76.230003  76.230003       0
# 217 2020-11-25  73.960800  74.169998  73.748802  73.960800  73.960800       0
# 255 2021-01-18  73.158997  73.419998  73.123001  73.158997  73.158997       0
# 186 2020-10-13  73.350800  73.504997  73.245598  73.350800  73.350800       0
# 121 2020-07-14  75.449997  75.510498  75.211800  75.449997  75.449997       0
# 12  2020-02-12  71.275497  71.474998  71.064003  71.275299  71.275299       0
# 123 2020-07-16  75.124901  75.349998  75.085999  75.124901  75.124901       0
# 216 2020-11-24  74.244499  74.249001  73.884399  74.244904  74.244904       0
# 150 2020-08-24  74.921799  74.921799  73.925301  74.921799  74.921799       0
# 101 2020-06-16  76.097504  76.283798  75.745003  75.977997  75.977997       0

# %%
data['Volume'].value_counts()
# Out:
# Volume
# 0    262
# Name: count, dtype: int64

# %%
columns = data.columns
for i in range(len(columns)):
    print(f'the data {columns[i]}---{data.iloc[:,i].nunique()}')
# Out:
# the data Date---262
# the data Open---255
# the data High---247
# the data Low---260
# the data Close---257
# the data Adj Close---257
# the data Volume---1

# %%
data.iloc[:,:].nunique()
# Out:
# Date         262
# Open         255
# High         247
# Low          260
# Close        257
# Adj Close    257
# Volume         1
# dtype: int64

# %%
data.iloc[1]
# Out:
# Date         2020-01-28 00:00:00
# Open                   71.654999
# High                   71.654999
# Low                    71.178001
# Close                  71.440002
# Adj Close              71.440002
# Volume                         0
# Name: 1, dtype: object

# %%
data[data.columns[1]]
# Out:
# 0      71.320000
# 1      71.654999
# 2      71.230103
# 3      71.300003
# 4      71.639999
#          ...
# 257    73.192001
# 258    72.907898
# 259    72.954903
# 260    72.995903
# 261    72.970001
# Name: Open, Length: 262, dtype: float64

# %%
data
# Out:
#           Date       Open       High        Low      Close  Adj Close  Volume
# 0   2020-01-27  71.320000  71.635002  71.320000  71.324997  71.324997       0
# 1   2020-01-28  71.654999  71.654999  71.178001  71.440002  71.440002       0
# 2   2020-01-29  71.230103  71.425003  71.168503  71.230400  71.230400       0
# 3   2020-01-30  71.300003  71.711998  71.300003  71.300003  71.300003       0
# 4   2020-01-31  71.639999  71.639999  71.277496  71.639999  71.639999       0
# ..         ...        ...        ...        ...        ...        ...     ...
# 257 2021-01-20  73.192001  73.192299  72.899300  73.191902  73.191902       0
# 258 2021-01-21  72.907898  73.045303  72.883003  72.910896  72.910896       0
# 259 2021-01-22  72.954903  73.237503  72.929001  72.954903  72.954903       0
# 260 2021-01-25  72.995903  73.220001  72.877998  72.995903  72.995903       0
# 261 2021-01-26  72.970001  73.222000  72.774498  72.970001  72.970001       0
#
# [262 rows x 7 columns]
# ...

# %%
from matplotlib import pyplot as plt
data['Open'].plot(kind='line', figsize=(8, 4), title='Open')
# plt.gca().spines[['top', 'right']].set_visible(False)
# Out:
# <Axes: title={'center': 'Open'}>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date']
  ys = series['Low']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data.sort_values('Date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date')
_ = plt.ylabel('Low')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date']
  ys = series['Open']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data.sort_values('Date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date')
_ = plt.ylabel('Open')

# %%
data['year'] = data['Date'].dt.year
data['month'] = data['Date'].dt.month
data['day'] = data['Date'].dt.day
data['day_of_week'] = data['Date'].dt.day_name()

# X = df[['year', 'month', 'day', 'day_of_week', 'open', 'high', 'low', 'volume']]
# y = df['close']
data
# Out:
#           Date       Open       High        Low      Close  Adj Close  Volume  \
# 0   2020-01-27  71.320000  71.635002  71.320000  71.324997  71.324997       0
# 1   2020-01-28  71.654999  71.654999  71.178001  71.440002  71.440002       0
# 2   2020-01-29  71.230103  71.425003  71.168503  71.230400  71.230400       0
# 3   2020-01-30  71.300003  71.711998  71.300003  71.300003  71.300003       0
# 4   2020-01-31  71.639999  71.639999  71.277496  71.639999  71.639999       0
# ..         ...        ...        ...        ...        ...        ...     ...
# 257 2021-01-20  73.192001  73.192299  72.899300  73.191902  73.191902       0
# 258 2021-01-21  72.907898  73.045303  72.883003  72.910896  72.910896       0
# 259 2021-01-22  72.954903  73.237503  72.929001  72.954903  72.954903       0
# 260 2021-01-25  72.995903  73.220001  72.877998  72.995903  72.995903       0
# 261 2021-01-26  72.970001  73.222000  72.774498  72.970001  72.970001       0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         262 non-null    datetime64[ns]
#  1   Open         262 non-null    float64
#  2   High         262 non-null    float64
#  3   Low          262 non-null    float64
#  4   Close        262 non-null    float64
#  5   Adj Close    262 non-null    float64
#  6   Volume       262 non-null    int64
#  7   year         262 non-null    int32
#  8   month        262 non-null    int32
#  9   day          262 non-null    int32
#  10  day_of_week  262 non-null    object
# dtypes: datetime64[ns](1), float64(5), int32(3), int64(1), object(1)
# memory usage: 19.6+ KB

# %%
x = data[['year','month','day','Open', 'High', 'Low', 'Volume']]
y = np.array(data['Close'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.3,random_state= 123)

# %%
y.mean()
# Out:
# 74.35848863358778

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (183, 7) (79, 7) (183,) (79,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

# %%
print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared: {r2:.2f}')
# Out:
# Mean Squared Error: 0.02
# R-squared: 0.99

# %%
x_test[0]
# Out:
# array([-0.27160724, -1.01629161, -0.77681982, -0.26731907,  0.28921559,
#        -0.11349524,  0.        ])

# %%
model.predict([x_test[0]])
# Out:
# array([74.18787466])

# %%
y_test[0]
# Out:
# 73.9953

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
X_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
X_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))

# %%
x_train,X_train
# Out:
# (array([[-0.27160724, -1.01629161,  0.01687798, ...,  0.32943774,
#          -0.19372217,  0.        ],
#         [ 3.68178701, -1.59388033,  0.24364878, ..., -0.81190367,
#          -0.67850745,  0.        ],
#         [-0.27160724,  0.4276802 , -1.23036142, ...,  0.41491399,
#           0.58086659,  0.        ],
#         ...,
#         [-0.27160724, -1.30508597,  0.35703418, ..., -1.88787924,
#          -1.97891296,  0.        ],
#         [-0.27160724,  1.58285764, -0.20989282, ..., -0.56989237,
#          -0.41338412,  0.        ],
#         [-0.27160724, -0.14990852, -0.55004902, ...,  1.049774  ,
#           1.13762483,  0.        ]]),
#  array([[[-0.27160724, -1.01629161,  0.01687798, ...,  0.32943774,
#           -0.19372217,  0.        ]],
#
#         [[ 3.68178701, -1.59388033,  0.24364878, ..., -0.81190367,
#           -0.67850745,  0.        ]],
#
#         [[-0.27160724,  0.4276802 , -1.23036142, ...,  0.41491399,
#            0.58086659,  0.        ]],
#
# ...

# %%
np.ndim(x_train)==np.ndim(X_train)
# Out:
# False

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(1, X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')


model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test), verbose=1)


score = model.evaluate(X_test, y_test, verbose=0)
print('Test MSE:', score)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 4s 189ms/step - loss: 5542.9673 - val_loss: 5495.8760
# Epoch 2/10
# 6/6 [==============================] - 0s 18ms/step - loss: 5532.0356 - val_loss: 5485.2676
# Epoch 3/10
# 6/6 [==============================] - 0s 17ms/step - loss: 5523.1338 - val_loss: 5475.5879
# Epoch 4/10
# 6/6 [==============================] - 0s 15ms/step - loss: 5512.4526 - val_loss: 5465.9907
# Epoch 5/10
# 6/6 [==============================] - 0s 13ms/step - loss: 5501.7974 - val_loss: 5455.7837
# Epoch 6/10
# 6/6 [==============================] - 0s 16ms/step - loss: 5488.5815 - val_loss: 5444.0435
# Epoch 7/10
# 6/6 [==============================] - 0s 21ms/step - loss: 5475.2480 - val_loss: 5430.3066
# Epoch 8/10
# 6/6 [==============================] - 0s 16ms/step - loss: 5460.8169 - val_loss: 5414.1572
# Epoch 9/10
# 6/6 [==============================] - 0s 17ms/step - loss: 5440.1475 - val_loss: 5395.2476
# Epoch 10/10
# ...
